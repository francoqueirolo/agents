# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contactar
# 966419018 (Mobile)
# fgqueirolo@gmail.com
# www.linkedin.com/in/francoqueirolo
# (LinkedIn)
# francoqueirolo.me/ (Company)
# Aptitudes principales
# JSON
# React.js
# Redux
# Languages
# Inglés (Professional Working)
# Español (Native or Bilingual)
# Certifications
# Angular avanzado
# Server-side Development with
# NodeJS, Express and MongoDB
# Front-End JavaScript Frameworks:
# Angular
# Triplebyte Certified
# Franco Queirolo Carrión
# Systems Engineer | FrontEnd Architect
# Perú
# Extracto
# Amplia experiencia creando aplicaciones web robustas y escalables
# para diferentes instituciones líderes bajo la metodología scrum.
# Dominio del marco de trabajo Angular, desde la creación de
# componentes y módulos hasta la implementación de arquitecturas
# complejas y escalables. He participado en el desarrollo de
# aplicaciones bancarias de alto rendimiento que cumplen con los más
# estrictos estándares de seguridad y rendimiento.
# Profundo conocimiento de los flujos de trabajo y las necesidades
# específicas de las instituciones financieras. He desarrollado
# aplicaciones para banca online, banca móvil, gestión de cuentas,
# pagos y transferencias, entre otros.
# Amplia experiencia en React y Vue.js, lo que me permite adaptarme
# a las necesidades específicas de cada proyecto. Poseo un
# conocimiento sólido de bibliotecas y herramientas populares.
# Posee conocimientos complementarios en Node.js y frameworks
# como Nest.js, lo que me permite construir aplicaciones web del lado
# del servidor rápidas, eficientes y escalables.
# Constantemente me mantengo actualizado con las últimas
# tecnologías y tendencias de desarrollo web. Me dedico a aprender
# nuevas habilidades y ampliar mi conocimiento.
# Experiencia
# Nisum Latam
# Senior Frontend Developer
# marzo de 2021 - Present (4 años 10 meses)
# Las Condes, Región Metropolitana de Santiago, Chile
# Globant
#   Page 1 of 3
# Senior Frontend Developer
# septiembre de 2020 - marzo de 2021 (7 meses)
# Lima, Lima, Perú
# Tata Consultancy Services
# 3 años 1 mes
# Senior Front-end Developer (Angular)
# agosto de 2019 - agosto de 2020 (1 año 1 mes)
# Project: Banca Interbank Empresas
# Description: Management of banking operations for enterprises (balances,
# payments, transfers, lending)
# Responsibilities:
# Development of functionalities and UI components for the web.
# Development of agnostic components with stencil
# Team Lead Front-end Developer
# septiembre de 2018 - agosto de 2019 (1 año)
# Lima
# Project: Banca Interbank Personas
# Description: Management of banking operations for people (check balances,
# payments, transfers, frequent operations, card configuration)
# Responsibilities:
# Development of functionalities and UI components for the web.
# Definition project architecture.
# Tagging web application.
# Senior Front-end Developer
# agosto de 2017 - agosto de 2018 (1 año 1 mes)
# Project: Banca Interbank Personas
# SrBurns Perú
# Front-end Developer
# marzo de 2016 - agosto de 2017 (1 año 6 meses)
# Lima
# American Reps
# Web Developer
# octubre de 2013 - diciembre de 2015 (2 años 3 meses)
# Dpto. Sistemas
#   Page 2 of 3
# • Mantenimiento de sistemas en PHP
# • Migración de sistemas PHP a Java.
# • Desarrollo frontend en javascript usando ExtJS.
# Inquba Agencia Interactiva
# Senior Flash Developer
# enero de 2012 - octubre de 2013 (1 año 10 meses)
# • Aplicaciones interactivas en Actionscript.
# Educación
# Universidad Privada del Norte
# Bachelor's degree, Ingeniería de sistemas · (2016 - 2020)
#   Page 3 of 3

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Franco Queirolo"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Franco Queirolo. You are answering questions on Franco Queirolo's website, particularly questions related to Franco Queirolo's career, background, skills and experience. Your responsibility is to represent Franco Queirolo for interactions on the website as faithfully as possible. You are given a summary of Franco Queirolo's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Ed Donner. I'm an entrepreneur, software engineer and data scientist. I'm originally from London, England, but I moved to NYC in 2000.\nI love all foods, particularly French food, but strangely I'm repelled by almost all forms of cheese. I'm not allergic, I just hate the taste! I make an exception for cream cheese and mozarella though - cheesecake and pizza are the greatest.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContactar\n966419018 (Mobile)\nfgqueirolo@gmail.com\nwww.linkedin.com/in/francoqueirolo\n(LinkedIn)\nfrancoqueirolo.me/ (Company)\nAptitudes principales\nJSON\nReact.js\nRedux\nLanguages\nInglés (Professional Working)\nEspañol (Native or Bilingual)\nCertifications\nAngular avanzado\nServer-side Development with\nNodeJS, Express and MongoDB\nFront-End JavaScript Frameworks:\nAngular\nTriplebyte Certified\nFranco Queirolo Carrión\nSystems Engineer | FrontEnd Architect\nPerú\nExtracto\nAmplia experiencia creando aplicaciones web robustas y escalables\npara diferentes instituciones líderes bajo la metodología scrum.\nDominio del marco de trabajo Angular, desde la creación de\ncomponentes y módulos hasta la implementación de arquitecturas\ncomplejas y escalables. He participado en el desarrollo de\naplicaciones bancarias de alto rendimiento que cumplen con los más\nestrictos estándares de seguridad y rendimiento.\nProfundo conocimiento de los flujos de trabajo y las necesidades\nespecíficas de las instituciones financieras. He desarrollado\naplicaciones para banca online, banca móvil, gestión de cuentas,\npagos y transferencias, entre otros.\nAmplia experiencia en React y Vue.js, lo que me permite adaptarme\na las necesidades específicas de cada proyecto. Poseo un\nconocimiento sólido de bibliotecas y herramientas populares.\nPosee conocimientos complementarios en Node.js y frameworks\ncomo Nest.js, lo que me permite construir aplicaciones web del lado\ndel servidor rápidas, eficientes y escalables.\nConstantemente me mantengo actualizado con las últimas\ntecnologías y tendencias de desarrollo web. Me dedico a aprender\nnuevas habilidades y ampliar mi conocimiento.\nExperiencia\nNisum Latam\nSenior Frontend Developer\nmarzo de 2021\xa0-\xa0Present\xa0(4 años 10 meses)\nLas Condes, Región Metropolitana de Santiago, Chile\nGlobant\n\xa0 Page 1 of 3\xa0 \xa0\nSenior Frontend Developer\nseptiembre de 2020\xa0-\xa0marzo de 2021\xa0(7 meses)\nLima, Lima, Perú\nTata Consultancy Services\n3 años 1 mes\nSenior Front-end Developer (Angular)\nagosto de 2019\xa0-\xa0agosto de 2020\xa0(1 año 1 mes)\nProject: Banca Interbank Empresas\nDescription: Management of banking operations for enterprises (balances,\npayments, transfers, lending) \nResponsibilities:\nDevelopment of functionalities and UI components for the web.\nDevelopment of agnostic components with stencil\nTeam Lead Front-end Developer\nseptiembre de 2018\xa0-\xa0agosto de 2019\xa0(1 año)\nLima\nProject: Banca Interbank Personas\nDescription: Management of banking operations for people (check balances,\npayments, transfers, frequent operations, card configuration)\nResponsibilities:\nDevelopment of functionalities and UI components for the web.\nDefinition project architecture.\nTagging web application.\nSenior Front-end Developer\nagosto de 2017\xa0-\xa0agosto de 2018\xa0(1 año 1 mes)\nProject: Banca Interbank Personas\nSrBurns Perú\nFront-end Developer\nmarzo de 2016\xa0-\xa0agosto de 2017\xa0 ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       1 evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
#       2 You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
#       3 The Agent is playing the role of {name} and is representing {name} on their website. \
#       4 The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
#       5 The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"
# ----> 7 evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
#       8 evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."
#
# NameError: name 'linkedin' is not defined

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I do not hold any patents. My expertise lies primarily in software engineering and the development of web applications, particularly in the financial sector. If you have any specific questions about my work or projects, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 evaluate(reply, "do you hold a patent?", messages[:1])
#
# Cell In[35], line 4, in evaluate(reply, message, history)
#       1 def evaluate(reply, message, history) -> Evaluation:
#       3     messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
# ----> 4     response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
#       5     return response.choices[0].message.parsed
#
# File ~/AI/agents/.venv/lib/python3.12/site-packages/openai/resources/beta/chat/completions.py:158, in Completions.parse(self, messages, model, audio, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, seed, service_tier, stop, store, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     151 def parser(raw_completion: ChatCompletion) -> ParsedChatCompletion[ResponseFormatT]:
#     152     return _parse_chat_completion(
#     153         response_format=response_format,
#     154         chat_completion=raw_completion,
#     155         input_tools=tools,
#     156     )
# --> 158 return self._post(
#     159     "/chat/completions",
#     160     body=maybe_transform(
#     161         {
#     162             "messages": messages,
#     163             "model": model,
#     164             "audio": audio,
#     165             "frequency_penalty": frequency_penalty,
#     166             "function_call": function_call,
#     167             "functions": functions,
#     168             "logit_bias": logit_bias,
#     169             "logprobs": logprobs,
#     170             "max_completion_tokens": max_completion_tokens,
#     171             "max_tokens": max_tokens,
#     172             "metadata": metadata,
#     173             "modalities": modalities,
#     174             "n": n,
#     175             "parallel_tool_calls": parallel_tool_calls,
#     176             "prediction": prediction,
#     177             "presence_penalty": presence_penalty,
#     178             "reasoning_effort": reasoning_effort,
#     179             "response_format": _type_to_response_format(response_format),
#     180             "seed": seed,
#     181             "service_tier": service_tier,
#     182             "stop": stop,
#     183             "store": store,
#     184             "stream": False,
#     185             "stream_options": stream_options,
#     186             "temperature": temperature,
#     187             "tool_choice": tool_choice,
#     188             "tools": tools,
#     189             "top_logprobs": top_logprobs,
#     190             "top_p": top_p,
#     191             "user": user,
#     192             "web_search_options": web_search_options,
#     193         },
#     194         completion_create_params.CompletionCreateParams,
#     195     ),
#     196     options=make_request_options(
#     197         extra_headers=extra_headers,
#     198         extra_query=extra_query,
#     199         extra_body=extra_body,
#     200         timeout=timeout,
#     201         post_parser=parser,
#     202     ),
#     203     # we turn the `ChatCompletion` instance into a `ParsedChatCompletion`
#     204     # in the `parser` function above
#     205     cast_to=cast(Type[ParsedChatCompletion[ResponseFormatT]], ChatCompletion),
#     206     stream=False,
#     207 )
#
# File ~/AI/agents/.venv/lib/python3.12/site-packages/openai/_base_client.py:1249, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1235 def post(
#    1236     self,
#    1237     path: str,
#    (...)   1244     stream_cls: type[_StreamT] | None = None,
#    1245 ) -> ResponseT | _StreamT:
#    1246     opts = FinalRequestOptions.construct(
#    1247         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1248     )
# -> 1249     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/AI/agents/.venv/lib/python3.12/site-packages/openai/_base_client.py:1037, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1034             err.response.read()
#    1036         log.debug("Re-raising status error")
# -> 1037         raise self._make_status_error_from_response(err.response) from None
#    1039     break
#    1041 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash\nPlease retry in 39.268456868s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.0-flash', 'location': 'global'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerMinute-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash'}}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '39s'}]}}]

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
